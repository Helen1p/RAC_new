# %%
import numpy as np
from PIL import Image
from torchvision import transforms
import os
import cv2
import torch
import pandas as pd
import math
# from label2rep import rep_label
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt

import time


def isdata(self, file, label):
    """
    :param file: original video
    :param label: original label
    :return: the number of load error
    """
    video_path = os.path.join(self.video_dir, file)
    cap = cv2.VideoCapture(video_path)
    frames_num = cap.get(7)
    if label.size == 0:
        # print('empty data:', file)
        self.error += 1
        return False
    elif frames_num >= max(label):
        return True
    else:
        # print("error data:", file, frames_num)
        # print('error data:', label)
        # print("error data:", len(label))
        self.error += 1
        return False


class MyDataset(Dataset):

    def __init__(self, root_dir, label_dir, frames, method):
        """
        :param root_dir: dataset root dir
        :param label_dir: dataset child dir
         # data_root = r'/data/train'
         # data_lable = data_root + 'label.xlsx'
         # data_video = data_root + 'video/'
        """
        super().__init__()
        self.root_dir = root_dir
        if method == 'train':
            self.video_dir = os.path.join(self.root_dir, r'train')
        elif method == 'valid':
            self.video_dir = os.path.join(self.root_dir, r'valid')
        elif method == 'test':
            self.video_dir = os.path.join(self.root_dir, r'test')
        else:
            raise ValueError('module is wrong.')
        # self.path = os.path.join(self.root_dir, self.child_dir)
        self.video_filename = os.listdir(self.video_dir)
        self.label_filename = os.path.join(self.root_dir, label_dir)
        self.file_list = []
        self.label_list = []
        self.num_idx = 4
        self.num_frames = frames  # model frames
        self.error = 0
        df = pd.read_csv(self.label_filename)
        for i in range(0, len(df)):
            filename = df.loc[i, 'name']
            label_tmp = df.values[i][self.num_idx:].astype(np.float64)
            label_tmp = label_tmp[~np.isnan(label_tmp)].astype(np.int32)
            # if self.isdata(filename, label_tmp):  # data is right format ,save in list
            self.file_list.append(filename)
            self.label_list.append(label_tmp)

    def __getitem__(self, index):
        """
        Save the preprocess frames and original video length in NPZ.
        npz[img = frames, fps = original_frames_length]
        """

        filename = self.file_list[index]
        video_path = os.path.join(self.video_dir, filename)
        npy_pth = npy_dir + os.path.splitext(filename)[0] + '.npz'
        if not os.path.exists(npy_pth):
            print('video :', filename, ' does not been saved to npz.')
            a = self.read_video(video_path, filename)
            if a == 1:
                print(index, filename, 'have been saved to npz.')
            else:
                print('error:', index, filename, 'can not be saved to npz.')
        else:
            try:
                data = np.load(npy_pth)
                print('good:', index, filename, 'loading success')
            except:
                print('error:', index, filename, 'is wrong npz which cant opened.')

        # uncomment to check data
        # y1, y2, num_period = self.adjust_label(self.label_list[index], original_frames_length, self.num_frames)
        # count = len(self.label_list[index]) / 2
        # if count == 0:
        #     print('file:', filename)
        # if count - num_period > 0.1:
        #     print('file:', filename)
        #     print('y1:', y1)
        #     print('y2:', y2)
        #     print('count:', count)
        #     print('sum_y:', num_period)
        return 1

    def __len__(self):
        return len(self.file_list)

    def read_video(self, video_filename, filename, width=224, height=224):
        """Read video from file."""
        try:
            cap = cv2.VideoCapture(video_filename)
            frames = []
            if cap.isOpened():
                while True:
                    success, frame_bgr = cap.read()
                    if success is False:
                        break
                    frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
                    frame_rgb = cv2.resize(frame_rgb, (width, height))
                    frames.append(frame_rgb)
            cap.release()
            original_frames_length = len(frames)
            frames = self.adjust_frames(frames)  # uncomment to adjust frames
            frames = np.asarray(frames)  # [f,h,w,c]
            if (frames.size != 0):
                frames = frames.transpose(0, 3, 2, 1)  # [f,c,h,w]
            else:
                print(filename, ' is wrong video. size = 0')
                return -1
            # npy_pth = r'/p300/LSP_npz/npy_data/' + os.path.splitext(filename)[0]
            npy_pth = npy_dir + os.path.splitext(filename)[0]
            np.savez(npy_pth, imgs=frames, fps=original_frames_length)  # [f,c,h,w]
        except:
            print('error: ', video_filename, ' cannot open')
        return 1

    def adjust_frames(self, frames):
        """
        # adjust the number of total video frames to the target frame num.
        :param frames: original frames
        :return: target number of frames
        """
        frames_adjust = []
        frame_length = len(frames)
        if self.num_frames <= len(frames):
            for i in range(1, self.num_frames + 1):
                frame = frames[i * frame_length // self.num_frames - 1]
                frames_adjust.append(frame)
        else:
            for i in range(frame_length):
                frame = frames[i]
                frames_adjust.append(frame)
            for _ in range(self.num_frames - frame_length):
                if len(frames) > 0:
                    frame = frames[-1]
                    frames_adjust.append(frame)
        return frames_adjust  # [f,h,w,3]


if __name__ == '__main__':
    data_root=r'/root/autodl-tmp/LLSP'
    tag = ['train', 'valid', 'test']
#     tag = ['valid', 'train', 'test']
    npy_dir = r'/root/autodl-tmp/LLSP/new_video/'
    for _ in range(3):
        mod = tag[_]
        label_file = mod + '.csv'
        test = MyDataset(data_root, label_file, 64, mod)
#         npy_dir = npy_dir + mod + '/'
        npy_dir = '/root/autodl-tmp/LLSP/new_video/' + mod + '/'
        print('=========================================')
        print(mod, ' : ', npy_dir)
        if not os.path.exists(npy_dir):
            os.mkdir(npy_dir)
        for i in range(len(test)):
            a = test[i]
# Out:
# =========================================
# train  :  /root/autodl-tmp/LLSP/new_video/train/
# video : train951.mp4  does not been saved to npz.
# 0 train951.mp4 have been saved to npz.
# video : train952.mp4  does not been saved to npz.
# 1 train952.mp4 have been saved to npz.
# video : test1463.mp4  does not been saved to npz.
# 2 test1463.mp4 have been saved to npz.
# video : test2340.mp4  does not been saved to npz.
# 3 test2340.mp4 have been saved to npz.
# video : stu5_11.mp4  does not been saved to npz.
# 4 stu5_11.mp4 have been saved to npz.
# video : stu9_2.mp4  does not been saved to npz.
# 5 stu9_2.mp4 have been saved to npz.
# video : stu6_18.mp4  does not been saved to npz.
# 6 stu6_18.mp4 have been saved to npz.
# video : stu4_14.mp4  does not been saved to npz.
# 7 stu4_14.mp4 have been saved to npz.
# video : stu8_3.mp4  does not been saved to npz.
# 8 stu8_3.mp4 have been saved to npz.
# video : stu4_54.mp4  does not been saved to npz.
# 9 stu4_54.mp4 have been saved to npz.
# video : test128.mp4  does not been saved to npz.
# 10 test128.mp4 have been saved to npz.
# video : stu4_66.mp4  does not been saved to npz.
# 11 stu4_66.mp4 have been saved to npz.
# 247 stu4_36.mp4 have been saved to npz.
# video : stu10_41.mp4  does not been saved to npz.
# 248 stu10_41.mp4 have been saved to npz.
# video : stu8_0.mp4  does not been saved to npz.
# 249 stu8_0.mp4 have been saved to npz.
# video : stu7_15.mp4  does not been saved to npz.
# 250 stu7_15.mp4 have been saved to npz.
# video : stu2_47.mp4  does not been saved to npz.
# 251 stu2_47.mp4 have been saved to npz.
# video : train2527.mp4  does not been saved to npz.
# 252 train2527.mp4 have been saved to npz.
# video : stu10_38.mp4  does not been saved to npz.
# 253 stu10_38.mp4 have been saved to npz.
# video : stu1_64.mp4  does not been saved to npz.
# 254 stu1_64.mp4 have been saved to npz.
# video : stu3_13.mp4  does not been saved to npz.
# 255 stu3_13.mp4 have been saved to npz.
# video : stu1_52.mp4  does not been saved to npz.
# 256 stu1_52.mp4 have been saved to npz.
# video : stu10_54.mp4  does not been saved to npz.
# 257 stu10_54.mp4 have been saved to npz.
# video : stu5_0.mp4  does not been saved to npz.
# 258 stu5_0.mp4 have been saved to npz.
# video : stu10_33.mp4  does not been saved to npz.
# 259 stu10_33.mp4 have been saved to npz.
# video : test558.mp4  does not been saved to npz.
# 260 test558.mp4 have been saved to npz.
# video : stu2_54.mp4  does not been saved to npz.
# 261 stu2_54.mp4 have been saved to npz.
# video : val581.mp4  does not been saved to npz.
# 262 val581.mp4 have been saved to npz.
# video : test989.mp4  does not been saved to npz.
# 263 test989.mp4 have been saved to npz.
# video : stu8_15.mp4  does not been saved to npz.
# 264 stu8_15.mp4 have been saved to npz.
# video : stu8_8.mp4  does not been saved to npz.
# 265 stu8_8.mp4 have been saved to npz.
# video : stu4_9.mp4  does not been saved to npz.
# 266 stu4_9.mp4 have been saved to npz.
# video : stu2_64.mp4  does not been saved to npz.
# 267 stu2_64.mp4 have been saved to npz.
# video : stu6_59.mp4  does not been saved to npz.
# 268 stu6_59.mp4 have been saved to npz.
# video : train929.mp4  does not been saved to npz.
# 269 train929.mp4 have been saved to npz.
# video : test555.mp4  does not been saved to npz.
# 270 test555.mp4 have been saved to npz.
# video : val1076.mp4  does not been saved to npz.
# 271 val1076.mp4 have been saved to npz.
# video : stu5_57.mp4  does not been saved to npz.
# 272 stu5_57.mp4 have been saved to npz.
# video : stu9_69.mp4  does not been saved to npz.
# 273 stu9_69.mp4 have been saved to npz.
# video : val828.mp4  does not been saved to npz.
# 274 val828.mp4 have been saved to npz.
# video : stu1_56.mp4  does not been saved to npz.
# 275 stu1_56.mp4 have been saved to npz.
# video : train2734.mp4  does not been saved to npz.
# 276 train2734.mp4 have been saved to npz.
# video : train2649.mp4  does not been saved to npz.
# 277 train2649.mp4 have been saved to npz.
# video : stu1_2.mp4  does not been saved to npz.
# 278 stu1_2.mp4 have been saved to npz.
# video : stu8_22.mp4  does not been saved to npz.
# 279 stu8_22.mp4 have been saved to npz.
# video : stu2_52.mp4  does not been saved to npz.
# 280 stu2_52.mp4 have been saved to npz.
# video : stu1_16.mp4  does not been saved to npz.
# 314 stu8_24.mp4 have been saved to npz.
# video : val892.mp4  does not been saved to npz.
# 315 val892.mp4 have been saved to npz.
# video : test557.mp4  does not been saved to npz.
# 316 test557.mp4 have been saved to npz.
# video : stu8_68.mp4  does not been saved to npz.
# 317 stu8_68.mp4 have been saved to npz.
# video : stu5_10.mp4  does not been saved to npz.
# 318 stu5_10.mp4 have been saved to npz.
# video : test1483.mp4  does not been saved to npz.
# 319 test1483.mp4 have been saved to npz.
# video : stu4_53.mp4  does not been saved to npz.
# 320 stu4_53.mp4 have been saved to npz.
# video : stu2_31.mp4  does not been saved to npz.
# 321 stu2_31.mp4 have been saved to npz.
# video : test570.mp4  does not been saved to npz.
# 322 test570.mp4 have been saved to npz.
# video : stu10_40.mp4  does not been saved to npz.
# 323 stu10_40.mp4 have been saved to npz.
# video : stu2_70.mp4  does not been saved to npz.
# 324 stu2_70.mp4 have been saved to npz.
# video : stu1_13.mp4  does not been saved to npz.
# 325 stu1_13.mp4 have been saved to npz.
# video : stu4_67.mp4  does not been saved to npz.
# 326 stu4_67.mp4 have been saved to npz.
# video : stu9_0.mp4  does not been saved to npz.
# 327 stu9_0.mp4 have been saved to npz.
# video : train1614.mp4  does not been saved to npz.
# 328 train1614.mp4 have been saved to npz.
# video : stu1_69.mp4  does not been saved to npz.
# 329 stu1_69.mp4 have been saved to npz.
# video : stu8_18.mp4  does not been saved to npz.
# 330 stu8_18.mp4 have been saved to npz.
# video : stu8_33.mp4  does not been saved to npz.
# 331 stu8_33.mp4 have been saved to npz.
# video : stu8_26.mp4  does not been saved to npz.
# 332 stu8_26.mp4 have been saved to npz.
# video : stu1_43.mp4  does not been saved to npz.
# 333 stu1_43.mp4 have been saved to npz.
# video : stu3_71.mp4  does not been saved to npz.
# 334 stu3_71.mp4 have been saved to npz.
# video : stu4_51.mp4  does not been saved to npz.
# 335 stu4_51.mp4 have been saved to npz.
# video : stu2_42.mp4  does not been saved to npz.
# 336 stu2_42.mp4 have been saved to npz.
# video : stu1_42.mp4  does not been saved to npz.
# 337 stu1_42.mp4 have been saved to npz.
# video : stu3_48.mp4  does not been saved to npz.
# 338 stu3_48.mp4 have been saved to npz.
# video : stu8_66.mp4  does not been saved to npz.
# 339 stu8_66.mp4 have been saved to npz.
# video : train1678.mp4  does not been saved to npz.
# 340 train1678.mp4 have been saved to npz.
# video : stu9_62.mp4  does not been saved to npz.
# 341 stu9_62.mp4 have been saved to npz.
# video : stu3_49.mp4  does not been saved to npz.
# 342 stu3_49.mp4 have been saved to npz.
# video : stu2_18.mp4  does not been saved to npz.
# 343 stu2_18.mp4 have been saved to npz.
# video : stu2_2.mp4  does not been saved to npz.
# 344 stu2_2.mp4 have been saved to npz.
# video : stu10_55.mp4  does not been saved to npz.
# 345 stu10_55.mp4 have been saved to npz.
# video : stu10_7.mp4  does not been saved to npz.
# 346 stu10_7.mp4 have been saved to npz.
# video : stu8_21.mp4  does not been saved to npz.
# 347 stu8_21.mp4 have been saved to npz.
# video : stu9_33.mp4  does not been saved to npz.
# 483 stu9_33.mp4 have been saved to npz.
# video : stu3_43.mp4  does not been saved to npz.
# 484 stu3_43.mp4 have been saved to npz.
# video : stu1_7.mp4  does not been saved to npz.
# 485 stu1_7.mp4 have been saved to npz.
# video : stu6_41.mp4  does not been saved to npz.
# 486 stu6_41.mp4 have been saved to npz.
# video : test2317.mp4  does not been saved to npz.
# 487 test2317.mp4 have been saved to npz.
# video : stu8_16.mp4  does not been saved to npz.
# 488 stu8_16.mp4 have been saved to npz.
# video : stu9_1.mp4  does not been saved to npz.
# 489 stu9_1.mp4 have been saved to npz.
# video : stu7_6.mp4  does not been saved to npz.
# 490 stu7_6.mp4 have been saved to npz.
# video : stu3_8.mp4  does not been saved to npz.
# 491 stu3_8.mp4 have been saved to npz.
# video : test1977.mp4  does not been saved to npz.
# 492 test1977.mp4 have been saved to npz.
# video : stu7_70.mp4  does not been saved to npz.
# 493 stu7_70.mp4 have been saved to npz.
# video : stu2_12.mp4  does not been saved to npz.
# 494 stu2_12.mp4 have been saved to npz.
# video : stu10_22.mp4  does not been saved to npz.
# 495 stu10_22.mp4 have been saved to npz.
# video : stu7_29.mp4  does not been saved to npz.
# 496 stu7_29.mp4 have been saved to npz.
# video : stu4_72.mp4  does not been saved to npz.
# 497 stu4_72.mp4 have been saved to npz.
# video : stu1_18.mp4  does not been saved to npz.
# 498 stu1_18.mp4 have been saved to npz.
# video : stu1_50.mp4  does not been saved to npz.
# 499 stu1_50.mp4 have been saved to npz.
# video : stu2_22.mp4  does not been saved to npz.
# 500 stu2_22.mp4 have been saved to npz.
# video : stu8_61.mp4  does not been saved to npz.
# 501 stu8_61.mp4 have been saved to npz.
# video : stu5_49.mp4  does not been saved to npz.
# 502 stu5_49.mp4 have been saved to npz.
# video : stu2_53.mp4  does not been saved to npz.
# 503 stu2_53.mp4 have been saved to npz.
# video : stu2_24.mp4  does not been saved to npz.
# 504 stu2_24.mp4 have been saved to npz.
# video : train2739.mp4  does not been saved to npz.
# 505 train2739.mp4 have been saved to npz.
# video : train960.mp4  does not been saved to npz.
# 506 train960.mp4 have been saved to npz.
# video : stu2_26.mp4  does not been saved to npz.
# 507 stu2_26.mp4 have been saved to npz.
# video : stu10_12.mp4  does not been saved to npz.
# 508 stu10_12.mp4 have been saved to npz.
# video : stu4_4.mp4  does not been saved to npz.
# 509 stu4_4.mp4 have been saved to npz.
# video : train1623.mp4  does not been saved to npz.
# 510 train1623.mp4 have been saved to npz.
# video : train3324.mp4  does not been saved to npz.
# 511 train3324.mp4 have been saved to npz.
# video : train172.mp4  does not been saved to npz.
# 512 train172.mp4 have been saved to npz.
# video : stu5_33.mp4  does not been saved to npz.
# 513 stu5_33.mp4 have been saved to npz.
# video : stu9_24.mp4  does not been saved to npz.
# 514 stu9_24.mp4 have been saved to npz.
# video : stu4_35.mp4  does not been saved to npz.
# 515 stu4_35.mp4 have been saved to npz.
# video : stu3_32.mp4  does not been saved to npz.
# video : stu9_52.mp4  does not been saved to npz.
# 19 stu9_52.mp4 have been saved to npz.
# video : stu1_27.mp4  does not been saved to npz.
# 20 stu1_27.mp4 have been saved to npz.
# video : stu10_24.mp4  does not been saved to npz.
# 21 stu10_24.mp4 have been saved to npz.
# video : stu10_25.mp4  does not been saved to npz.
# 22 stu10_25.mp4 have been saved to npz.
# video : stu9_48.mp4  does not been saved to npz.
# 23 stu9_48.mp4 have been saved to npz.
# video : stu10_48.mp4  does not been saved to npz.
# 24 stu10_48.mp4 have been saved to npz.
# video : train2508.mp4  does not been saved to npz.
# 25 train2508.mp4 have been saved to npz.
# video : stu10_36.mp4  does not been saved to npz.
# 26 stu10_36.mp4 have been saved to npz.
# video : stu6_63.mp4  does not been saved to npz.
# 27 stu6_63.mp4 have been saved to npz.
# video : stu4_69.mp4  does not been saved to npz.
# 28 stu4_69.mp4 have been saved to npz.
# video : stu3_31.mp4  does not been saved to npz.
# 29 stu3_31.mp4 have been saved to npz.
# video : stu10_5.mp4  does not been saved to npz.
# 30 stu10_5.mp4 have been saved to npz.
# video : stu5_47.mp4  does not been saved to npz.
# 31 stu5_47.mp4 have been saved to npz.
# video : stu6_15.mp4  does not been saved to npz.
# 32 stu6_15.mp4 have been saved to npz.
# video : stu8_70.mp4  does not been saved to npz.
# 33 stu8_70.mp4 have been saved to npz.
# video : stu8_38.mp4  does not been saved to npz.
# 34 stu8_38.mp4 have been saved to npz.
# video : stu4_64.mp4  does not been saved to npz.
# 35 stu4_64.mp4 have been saved to npz.
# video : stu5_62.mp4  does not been saved to npz.
# 36 stu5_62.mp4 have been saved to npz.
# video : stu10_1.mp4  does not been saved to npz.
# 37 stu10_1.mp4 have been saved to npz.
# video : stu7_35.mp4  does not been saved to npz.
# 38 stu7_35.mp4 have been saved to npz.
# video : stu2_55.mp4  does not been saved to npz.
# 39 stu2_55.mp4 have been saved to npz.
# video : stu2_25.mp4  does not been saved to npz.
# 40 stu2_25.mp4 have been saved to npz.
# video : stu6_30.mp4  does not been saved to npz.
# 41 stu6_30.mp4 have been saved to npz.
# video : stu8_9.mp4  does not been saved to npz.
# 42 stu8_9.mp4 have been saved to npz.
# video : stu8_12.mp4  does not been saved to npz.
# 43 stu8_12.mp4 have been saved to npz.
# video : test538.mp4  does not been saved to npz.
# 44 test538.mp4 have been saved to npz.
# video : stu5_18.mp4  does not been saved to npz.
# 45 stu5_18.mp4 have been saved to npz.
# video : stu5_27.mp4  does not been saved to npz.
# 46 stu5_27.mp4 have been saved to npz.
# video : stu7_8.mp4  does not been saved to npz.
# 47 stu7_8.mp4 have been saved to npz.
# video : stu9_36.mp4  does not been saved to npz.
# 48 stu9_36.mp4 have been saved to npz.
# video : stu1_40.mp4  does not been saved to npz.
# 49 stu1_40.mp4 have been saved to npz.
# video : test536.mp4  does not been saved to npz.
# 50 test536.mp4 have been saved to npz.
# video : stu4_63.mp4  does not been saved to npz.
# 51 stu4_63.mp4 have been saved to npz.
# video : stu4_46.mp4  does not been saved to npz.
# 52 stu4_46.mp4 have been saved to npz.
# video : stu3_58.mp4  does not been saved to npz.
# 53 stu3_58.mp4 have been saved to npz.
# video : stu7_30.mp4  does not been saved to npz.
# 54 stu7_30.mp4 have been saved to npz.
# video : stu8_10.mp4  does not been saved to npz.
# 55 stu8_10.mp4 have been saved to npz.
# video : stu5_12.mp4  does not been saved to npz.
# 56 stu5_12.mp4 have been saved to npz.
# video : stu9_17.mp4  does not been saved to npz.
# 57 stu9_17.mp4 have been saved to npz.
# video : train1665.mp4  does not been saved to npz.
# 58 train1665.mp4 have been saved to npz.
# video : stu1_59.mp4  does not been saved to npz.
# 59 stu1_59.mp4 have been saved to npz.
# video : test2025.mp4  does not been saved to npz.
# 60 test2025.mp4 have been saved to npz.
# video : stu10_6.mp4  does not been saved to npz.
# 61 stu10_6.mp4 have been saved to npz.
# video : stu8_71.mp4  does not been saved to npz.
# 62 stu8_71.mp4 have been saved to npz.
# video : stu7_52.mp4  does not been saved to npz.
# 63 stu7_52.mp4 have been saved to npz.
# video : stu4_19.mp4  does not been saved to npz.
# 64 stu4_19.mp4 have been saved to npz.
# video : stu3_10.mp4  does not been saved to npz.
# 65 stu3_10.mp4 have been saved to npz.
# video : test2315.mp4  does not been saved to npz.
# 66 test2315.mp4 have been saved to npz.
# video : stu8_45.mp4  does not been saved to npz.
# 67 stu8_45.mp4 have been saved to npz.
# video : test2320.mp4  does not been saved to npz.
# 68 test2320.mp4 have been saved to npz.
# video : stu4_29.mp4  does not been saved to npz.
# 69 stu4_29.mp4 have been saved to npz.
# video : stu9_47.mp4  does not been saved to npz.
# 70 stu9_47.mp4 have been saved to npz.
# video : val579.mp4  does not been saved to npz.
# 71 val579.mp4 have been saved to npz.
# video : stu2_62.mp4  does not been saved to npz.
# 72 stu2_62.mp4 have been saved to npz.
# video : stu6_68.mp4  does not been saved to npz.
# 73 stu6_68.mp4 have been saved to npz.
# video : stu2_34.mp4  does not been saved to npz.
# 74 stu2_34.mp4 have been saved to npz.
# video : stu10_43.mp4  does not been saved to npz.
# 75 stu10_43.mp4 have been saved to npz.
# video : test2021.mp4  does not been saved to npz.
# 76 test2021.mp4 have been saved to npz.
# video : stu3_28.mp4  does not been saved to npz.
# 77 stu3_28.mp4 have been saved to npz.
# video : stu9_71.mp4  does not been saved to npz.
# 78 stu9_71.mp4 have been saved to npz.
# video : stu2_5.mp4  does not been saved to npz.
# 79 stu2_5.mp4 have been saved to npz.
# video : stu9_45.mp4  does not been saved to npz.
# 80 stu9_45.mp4 have been saved to npz.
# video : stu4_12.mp4  does not been saved to npz.
# 81 stu4_12.mp4 have been saved to npz.
# video : stu6_22.mp4  does not been saved to npz.
# 82 stu6_22.mp4 have been saved to npz.
# video : stu7_17.mp4  does not been saved to npz.
# 83 stu7_17.mp4 have been saved to npz.
# video : stu3_5.mp4  does not been saved to npz.
# 84 stu3_5.mp4 have been saved to npz.
# video : stu5_32.mp4  does not been saved to npz.
# 85 stu5_32.mp4 have been saved to npz.
# video : stu9_31.mp4  does not been saved to npz.
# 86 stu9_31.mp4 have been saved to npz.
# video : stu6_42.mp4  does not been saved to npz.
# 87 stu6_42.mp4 have been saved to npz.
# video : stu7_13.mp4  does not been saved to npz.
# 88 stu7_13.mp4 have been saved to npz.
# video : stu6_65.mp4  does not been saved to npz.
# 89 stu6_65.mp4 have been saved to npz.
# video : stu3_20.mp4  does not been saved to npz.
# 90 stu3_20.mp4 have been saved to npz.
# video : stu5_68.mp4  does not been saved to npz.
# 91 stu5_68.mp4 have been saved to npz.
# video : stu8_28.mp4  does not been saved to npz.
# 92 stu8_28.mp4 have been saved to npz.
# video : stu6_24.mp4  does not been saved to npz.
# 93 stu6_24.mp4 have been saved to npz.
# video : stu6_39.mp4  does not been saved to npz.
# 94 stu6_39.mp4 have been saved to npz.
# video : stu3_57.mp4  does not been saved to npz.
# 95 stu3_57.mp4 have been saved to npz.
# video : train2659.mp4  does not been saved to npz.
# 96 train2659.mp4 have been saved to npz.
# video : stu8_11.mp4  does not been saved to npz.
# 97 stu8_11.mp4 have been saved to npz.
# video : stu3_25.mp4  does not been saved to npz.
# 98 stu3_25.mp4 have been saved to npz.
# video : stu4_28.mp4  does not been saved to npz.
# 99 stu4_28.mp4 have been saved to npz.
# video : stu10_19.mp4  does not been saved to npz.
# 100 stu10_19.mp4 have been saved to npz.
# video : stu8_25.mp4  does not been saved to npz.
# 101 stu8_25.mp4 have been saved to npz.
# video : stu3_39.mp4  does not been saved to npz.
# 102 stu3_39.mp4 have been saved to npz.
# video : train2534.mp4  does not been saved to npz.
# 103 train2534.mp4 have been saved to npz.
# video : stu1_30.mp4  does not been saved to npz.
# 104 stu1_30.mp4 have been saved to npz.
# video : stu2_65.mp4  does not been saved to npz.
# 105 stu2_65.mp4 have been saved to npz.
# video : train3335.mp4  does not been saved to npz.
# 106 train3335.mp4 have been saved to npz.
# video : stu1_60.mp4  does not been saved to npz.
# 107 stu1_60.mp4 have been saved to npz.
# video : test534.mp4  does not been saved to npz.
# 108 test534.mp4 have been saved to npz.
# video : stu10_60.mp4  does not been saved to npz.
# 109 stu10_60.mp4 have been saved to npz.
# video : stu6_13.mp4  does not been saved to npz.
# 110 stu6_13.mp4 have been saved to npz.
# video : stu6_23.mp4  does not been saved to npz.
# 111 stu6_23.mp4 have been saved to npz.
# video : stu8_23.mp4  does not been saved to npz.
# 112 stu8_23.mp4 have been saved to npz.
# video : stu4_68.mp4  does not been saved to npz.
# 113 stu4_68.mp4 have been saved to npz.
# video : stu9_34.mp4  does not been saved to npz.
# 114 stu9_34.mp4 have been saved to npz.
# video : test1454.mp4  does not been saved to npz.
# 115 test1454.mp4 have been saved to npz.
# video : stu3_55.mp4  does not been saved to npz.
# 116 stu3_55.mp4 have been saved to npz.
# video : stu5_55.mp4  does not been saved to npz.
# 117 stu5_55.mp4 have been saved to npz.
# video : train3899.mp4  does not been saved to npz.
# 118 train3899.mp4 have been saved to npz.
